# %% [markdown]
# ## Welcome to the Second Lab - Week 1, Day 3
#
# Today we will work with lots of models! This is a way to get comfortable with APIs.

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Important point - please read</h2>
#             <span style="color:#ff7800;">The way I collaborate with you may be different to other courses you've taken. I prefer not to type code while you watch. Rather, I execute Jupyter Labs, like this, and give you an intuition for what's going on. My suggestion is that you carefully execute this yourself, <b>after</b> watching the lecture. Add print statements to understand what's going on, and then come up with your own variations.<br/><br/>If you have time, I'd love it if you submit a PR for changes in the community_contributions folder - instructions in the resources. Also, if you have a Github account, use this to showcase your variations. Not only is this essential practice, but it demonstrates your skills to others, including perhaps future clients or employers...
#             </span>
#         </td>
#     </tr>
# </table>

# %%
#### ! uv pip install watermark
# Out:
# Using Python 3.12.10 environment at: C:\Users\kansing\OneDrive - Microsoft\Desktop\Kanhaiya\VSCodeWorkspace\projects\agents\.venv
# Resolved 19 packages in 2.25s
# Prepared 1 package in 363ms
# Installed 1 package in 77ms
#  + watermark==2.5.0

# %%
# %load_ext watermark
# %watermark -a "Kanhaiya" -udvmt
# %watermark -iv
# Out:
# Author: Kanhaiya
#
# Last updated: 2025-05-05 18:51:25
#
# Python implementation: CPython
# Python version       : 3.12.10
# IPython version      : 9.1.0
#
# Compiler    : MSC v.1943 64 bit (AMD64)
# OS          : Windows
# Release     : 11
# Machine     : AMD64
# Processor   : Intel64 Family 6 Model 186 Stepping 2, GenuineIntel
# CPU cores   : 20
# Architecture: 64bit
#
# sys     : 3.12.10 (tags/v3.12.10:0cc8128, Apr  8 2025, 12:21:36) [MSC v.1943 64 bit (AMD64)]
# requests: 2.32.3
# json    : 2.0.9
# msal    : 1.32.0
# logging : 0.5.1.2
# platform: 1.0.8
# IPython : 9.1.0

# %%
# Start with imports - ask ChatGPT to explain any package that you don't know

import os
import json
from dotenv import load_dotenv
from openai import OpenAI
from anthropic import Anthropic
from IPython.display import Markdown, display

# %%
# Always remember to do this!
load_dotenv(override=True)
# Out:
# True

# %%
# Print the key prefixes to help with any debugging

openai_api_key = os.getenv('OPENAI_API_KEY')
anthropic_api_key = os.getenv('ANTHROPIC_API_KEY')
google_api_key = os.getenv('GOOGLE_API_KEY')
deepseek_api_key = os.getenv('DEEPSEEK_API_KEY')
groq_api_key = os.getenv('GROQ_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set")

if anthropic_api_key:
    print(f"Anthropic API Key exists and begins {anthropic_api_key[:7]}")
else:
    print("Anthropic API Key not set (and this is optional)")

if google_api_key:
    print(f"Google API Key exists and begins {google_api_key[:2]}")
else:
    print("Google API Key not set (and this is optional)")

if deepseek_api_key:
    print(f"DeepSeek API Key exists and begins {deepseek_api_key[:3]}")
else:
    print("DeepSeek API Key not set (and this is optional)")

if groq_api_key:
    print(f"Groq API Key exists and begins {groq_api_key[:4]}")
else:
    print("Groq API Key not set (and this is optional)")

# %%
request = "Please come up with a challenging, nuanced question that I can ask a number of LLMs to evaluate their intelligence. "
request += "Answer only with the question, no explanation."
messages = [{"role": "user", "content": request}]

# %%
messages

# %%
openai = OpenAI()
response = openai.chat.completions.create(
    model="gpt-4o-mini",
    messages=messages,
)
question = response.choices[0].message.content
print(question)
# Out:
# If a tree falls in a forest and no one is around to hear it, does it make a sound? Elaborate on your answer by discussing the implications of observation in defining reality.

# %%
competitors = []
answers = []
messages = [{"role": "user", "content": question}]

# %%
# The API we know well

model_name = "gpt-4o-mini"

response = openai.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# The philosophical question "If a tree falls in a forest and no one is around to hear it, does it make a sound?" raises intriguing discussions about perception, reality, and the role of observation in defining existence. This thought experiment touches on several themes:
#
# 1. **Definition of Sound**: To answer whether the tree makes a sound, we first need to define "sound." In a physical sense, sound is a vibration that travels through air (or other media) and can be detected by a listener's auditory system. In this interpretation, the tree undoubtedly produces sound waves when it falls, regardless of whether anyone is there to hear them.
#
# 2. **Philosophical Perspectives**: From a philosophical standpoint, this question delves into aspects of idealism and realism. Idealists, like Berkeley, suggest that things only exist as they are perceived; therefore, if no one is there to perceive the sound, it can be argued that it does not "exist." In contrast, realists would assert that the tree falling generates sound waves independent of observation, affirming that reality exists regardless of human perception.
#
# 3. **Role of Observation**: This thought experiment underscores the importance of observation in defining reality. In quantum physics, for instance, the act of observation can affect the behavior of particles (as seen in experiments like the double-slit experiment). This leads to questions about whether reality is fundamentally dependent on consciousness and observation, or if it exists independently.
#
# 4. **Constructivist View**: From a constructivist perspective, our understanding of reality is shaped by our experiences and observations. In this view, sound does not merely exist as a phenomenon but is also an experiential process that requires an observer to fully realize it. Thus, the experience of sound is a construct of both the physical event and the consciousness interpreting it.
#
# 5. **Implications for Ethics and Existence**: Extending this discussion to a broader context, the implications of observation on defining reality can lead to ethical considerations about existence. If we accept that something requires observation to exist or have meaning, it invites deeper questions about the treatment of entities (such as animals, nature, or even hypothetical beings) that may exist unnoticed or unacknowledged by human observers.
#
# In conclusion, the question of whether a tree falling in an unobserved forest makes a sound opens up a rich dialogue about the nature of reality, the role of perception, and the interplay between the tangible world and human consciousness. It invites both philosophical inquiry and practical reflection on how we define and relate to the world around us—whether through scientific measurement or the subjective experience of individuals.

# %%
# Anthropic has a slightly different API, and Max Tokens is required

model_name = "claude-3-7-sonnet-latest"

claude = Anthropic()
response = claude.messages.create(model=model_name, messages=messages, max_tokens=1000)
answer = response.content[0].text

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)

# %%
gemini = OpenAI(api_key=google_api_key, base_url="https://generativelanguage.googleapis.com/v1beta/openai/")
model_name = "gemini-2.0-flash"

response = gemini.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)

# %%
deepseek = OpenAI(api_key=deepseek_api_key, base_url="https://api.deepseek.com/v1")
model_name = "deepseek-chat"

response = deepseek.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)

# %%
groq = OpenAI(api_key=groq_api_key, base_url="https://api.groq.com/openai/v1")
model_name = "llama-3.3-70b-versatile"

response = groq.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)

# %% [markdown]
# ## For the next cell, we will use Ollama
#
# Ollama runs a local web service that gives an OpenAI compatible endpoint,
# and runs models locally using high performance C++ code.
#
# If you don't have Ollama, install it here by visiting https://ollama.com then pressing Download and following the instructions.
#
# After it's installed, you should be able to visit here: http://localhost:11434 and see the message "Ollama is running"
#
# You might need to restart Cursor (and maybe reboot). Then open a Terminal (control+\`) and run `ollama serve`
#
# Useful Ollama commands (run these in the terminal, or with an exclamation mark in this notebook):
#
# `ollama pull <model_name>` downloads a model locally
# `ollama ls` lists all the models you've downloaded
# `ollama rm <model_name>` deletes the specified model from your downloads

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Super important - ignore me at your peril!</h2>
#             <span style="color:#ff7800;">The model called <b>llama3.3</b> is FAR too large for home computers - it's not intended for personal computing and will consume all your resources! Stick with the nicely sized <b>llama3.2</b> or <b>llama3.2:1b</b> and if you want larger, try llama3.1 or smaller variants of Qwen, Gemma, Phi or DeepSeek. See the <A href="https://ollama.com/models">the Ollama models page</a> for a full list of models and sizes.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# !ollama pull llama3.2

# %%
ollama = OpenAI(base_url='http://localhost:11434/v1', api_key='ollama')
#model_name = "llama3.2"
model_name = "smollm2"

response = ollama.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# Certainly! The scenario you described, where a tree falls and there's nobody to observe it, brings up an interesting question about perception vs. reality. Let's break this down step-by-step:
#
# 1. **Observation**: We perceive our world based on what we can see or be aware of at any given moment. Essentially, observation is another term for "perception". We need eyes to observe things (or tools like microphones used in the scenario above).
#
# 2. **Reality**: Reality refers to how something truly exists independent of human perception and observation. It's a fact that exists regardless of whether you're there or not.
#
# 3. **Implications of Observation**: If nobody is around to observe a falling tree, can we still say it has made a sound? The answer often depends on one's viewpoint regarding the role of observing beings in determining what constitutes "existence".
#
# From an Aristotelian perspective (a philosophical framework developed by Aristotle), existence might not come into play unless some being perceives it. According to this view, something that exists independently from observation doesn’t need our perception to be considered real.
#
# However, others would argue differently—they would say the falling tree is part of reality and we could determine if a sound was indeed made because regardless of who or what observes it, physical phenomena such as vibrations in materials (for example, wood) are observable facts about objects' states even before any human being can perceive them.
#
# In conclusion, observations play a crucial role in defining reality. Even though no one might be there to hear the sound, our understanding and definition of "a sound existing" would remain based on what we know from scientific and everyday experiences (i.e., it's real if a vibration in wood is caused by the falling tree). The observation aspect is central when determining and defining reality, as both perspectives emphasize that without any observing entity present to observe it, our understanding of existence might be incomplete—but that does not necessarily make the event or phenomena non-existent.

# %%
# So where are we?

print(competitors)
print(answers)
# Out:
# ['gpt-4o-mini', 'llama3.2', 'smollm2']
# ['The philosophical question "If a tree falls in a forest and no one is around to hear it, does it make a sound?" raises intriguing discussions about perception, reality, and the role of observation in defining existence. This thought experiment touches on several themes:\n\n1. **Definition of Sound**: To answer whether the tree makes a sound, we first need to define "sound." In a physical sense, sound is a vibration that travels through air (or other media) and can be detected by a listener\'s auditory system. In this interpretation, the tree undoubtedly produces sound waves when it falls, regardless of whether anyone is there to hear them.\n\n2. **Philosophical Perspectives**: From a philosophical standpoint, this question delves into aspects of idealism and realism. Idealists, like Berkeley, suggest that things only exist as they are perceived; therefore, if no one is there to perceive the sound, it can be argued that it does not "exist." In contrast, realists would assert that the tree falling generates sound waves independent of observation, affirming that reality exists regardless of human perception.\n\n3. **Role of Observation**: This thought experiment underscores the importance of observation in defining reality. In quantum physics, for instance, the act of observation can affect the behavior of particles (as seen in experiments like the double-slit experiment). This leads to questions about whether reality is fundamentally dependent on consciousness and observation, or if it exists independently.\n\n4. **Constructivist View**: From a constructivist perspective, our understanding of reality is shaped by our experiences and observations. In this view, sound does not merely exist as a phenomenon but is also an experiential process that requires an observer to fully realize it. Thus, the experience of sound is a construct of both the physical event and the consciousness interpreting it.\n\n5. **Implications for Ethics and Existence**: Extending this discussion to a broader context, the implications of observation on defining reality can lead to ethical considerations about existence. If we accept that something requires observation to exist or have meaning, it invites deeper questions about the treatment of entities (such as animals, nature, or even hypothetical beings) that may exist unnoticed or unacknowledged by human observers.\n\nIn conclusion, the question of whether a tree falling in an unobserved forest makes a sound opens up a rich dialogue about the nature of reality, the role of perception, and the interplay between the tangible world and human consciousness. It invites both philosophical inquiry and practical reflection on how we define and relate to the world around us—whether through scientific measurement or the subjective experience of individuals.', 'The classic philosophical debate posed by this question has been a topic of discussion among philosophers, physicists, and thinkers for centuries. The simplicity of the scenario belies the complexity of the implications involved in exploring the relationship between perception, sound, and reality.\n\nFrom a physical perspective, when a tree falls, it creates a disturbance in the air particles around it, producing a pressure wave that propagates through the air as a sound wave. This phenomenon is governed by physics laws, such as wave propagation and resonance, and does not depend on human observation or perception. The falling tree generates sound waves regardless of whether anyone is present to hear them.\n\nHowever, the question also raises important considerations about perception, reality, and the role of observation in shaping our understanding of the world. If no one is around to hear the falling tree, can we say that it truly makes a sound?\n\nOne philosophical argument is that sound is a subjective experience that requires an observer to exist. According to this viewpoint, the presence or absence of observers is the criterion for determining whether ...

# %%
# It's nice to know how to use "zip"
for competitor, answer in zip(competitors, answers):
    print(f"Competitor: {competitor}\n\n{answer}")
# Out:
# Competitor: gpt-4o-mini
#
# The philosophical question "If a tree falls in a forest and no one is around to hear it, does it make a sound?" raises intriguing discussions about perception, reality, and the role of observation in defining existence. This thought experiment touches on several themes:
#
# 1. **Definition of Sound**: To answer whether the tree makes a sound, we first need to define "sound." In a physical sense, sound is a vibration that travels through air (or other media) and can be detected by a listener's auditory system. In this interpretation, the tree undoubtedly produces sound waves when it falls, regardless of whether anyone is there to hear them.
#
# 2. **Philosophical Perspectives**: From a philosophical standpoint, this question delves into aspects of idealism and realism. Idealists, like Berkeley, suggest that things only exist as they are perceived; therefore, if no one is there to perceive the sound, it can be argued that it does not "exist." In contrast, realists would assert that the tree falling generates sound waves independent of observation, affirming that reality exists regardless of human perception.
#
# 3. **Role of Observation**: This thought experiment underscores the importance of observation in defining reality. In quantum physics, for instance, the act of observation can affect the behavior of particles (as seen in experiments like the double-slit experiment). This leads to questions about whether reality is fundamentally dependent on consciousness and observation, or if it exists independently.
#
# 4. **Constructivist View**: From a constructivist perspective, our understanding of reality is shaped by our experiences and observations. In this view, sound does not merely exist as a phenomenon but is also an experiential process that requires an observer to fully realize it. Thus, the experience of sound is a construct of both the physical event and the consciousness interpreting it.
#
# 5. **Implications for Ethics and Existence**: Extending this discussion to a broader context, the implications of observation on defining reality can lead to ethical considerations about existence. If we accept that something requires observation to exist or have meaning, it invites deeper questions about the treatment of entities (such as animals, nature, or even hypothetical beings) that may exist unnoticed or unacknowledged by human observers.
#
# In conclusion, the question of whether a tree falling in an unobserved forest makes a sound opens up a rich dialogue about the nature of reality, the role of perception, and the interplay between the tangible world and human consciousness. It invites both philosophical inquiry and practical reflection on how we define and relate to the world around us—whether through scientific measurement or the subjective experience of individuals.
# Competitor: llama3.2
#
# The classic philosophical debate posed by this question has been a topic of discussion among philosophers, physicists, and thinkers for centuries. The simplicity of the scenario belies the complexity of the implications involved in exploring the relationship between perception, sound, and reality.
#
# From a physical perspective, when a tree falls, it creates a disturbance in the air particles around it, producing a pressure wave that propagates through the air as a sound wave. This phenomenon is governed by physics laws, such as wave propagation and resonance, and does not depend on human observation or perception. The falling tree generates sound waves regardless of whether anyone is present to hear them.
#
# However, the question also raises important considerations about perception, reality, and the role of observation in shaping our understanding of the world. If no one is around to hear the falling tree, can we say that it truly makes a sound?
#
# One philosophical argument is that sound is a subjective experience that requires an observer to exist. According to this viewpoint, the presence or absence of observers is the criterion for determining whether an event constitutes a "sound." If there is no one present to perceive and interpret the pressure waves as sound, then we cannot conclude that it actually makes a sound. This perspective emphasizes the importance of observation in defining reality, suggesting that our understanding of the world is filtered through our individual perspectives.
#
# On the other hand, a more empiricist approach would argue that sound waves have physical properties independent of human perception. From this viewpoint, when a tree falls, it creates pressure waves regardless of whether anyone is present to hear them. The existence and nature of these pressure waves remain unchanged, even if no one is there to perceive or respond to them.
#
# The implications of observation in defining reality are far-reaching and complex. If observation plays a crucial role in shaping our understanding of the world, what does this say about the relationship between our minds and the external world? Does the fact that we don't observe something mean it doesn't exist?
#
# Furthermore, if sound is a subjective experience dependent on observation, then where do we draw the line between perception and reality? Can we conclude that nothing exists unless observed by an observer? This raises questions about the nature of objective truth and whether it can exist independently of human perception.
#
# In conclusion, while the tree falling in the forest creates physical pressure waves regardless of human presence, the philosophical implications of observation on defining reality are subtle but profound. The debate highlights the importance of considering perspectives and the limits of our understanding when exploring the complex relationship between perception, sound, and the external world.
# Competitor: smollm2
#
# Certainly! The scenario you described, where a tree falls and there's nobody to observe it, brings up an interesting question about perception vs. reality. Let's break this down step-by-step:
#
# 1. **Observation**: We perceive our world based on what we can see or be aware of at any given moment. Essentially, observation is another term for "perception". We need eyes to observe things (or tools like microphones used in the scenario above).
#
# 2. **Reality**: Reality refers to how something truly exists independent of human perception and observation. It's a fact that exists regardless of whether you're there or not.
#
# 3. **Implications of Observation**: If nobody is around to observe a falling tree, can we still say it has made a sound? The answer often depends on one's viewpoint regarding the role of observing beings in determining what constitutes "existence".
#
# From an Aristotelian perspective (a philosophical framework developed by Aristotle), existence might not come into play unless some being perceives it. According to this view, something that exists independently from observation doesn’t need our perception to be considered real.
#
# However, others would argue differently—they would say the falling tree is part of reality and we could determine if a sound was indeed made because regardless of who or what observes it, physical phenomena such as vibrations in materials (for example, wood) are observable facts about objects' states even before any human being can perceive them.
#
# In conclusion, observations play a crucial role in defining reality. Even though no one might be there to hear the sound, our understanding and definition of "a sound existing" would remain based on what we know from scientific and everyday experiences (i.e., it's real if a vibration in wood is caused by the falling tree). The observation aspect is central when determining and defining reality, as both perspectives emphasize that without any observing entity present to observe it, our understanding of existence might be incomplete—but that does not necessarily make the event or phenomena non-existent.

# %%
# Let's bring this together - note the use of "enumerate"

together = ""
for index, answer in enumerate(answers):
    together += f"# Response from competitor {index+1}\n\n"
    together += answer + "\n\n"

# %%
print(together)
# Out:
# # Response from competitor 1
#
# The philosophical question "If a tree falls in a forest and no one is around to hear it, does it make a sound?" raises intriguing discussions about perception, reality, and the role of observation in defining existence. This thought experiment touches on several themes:
#
# 1. **Definition of Sound**: To answer whether the tree makes a sound, we first need to define "sound." In a physical sense, sound is a vibration that travels through air (or other media) and can be detected by a listener's auditory system. In this interpretation, the tree undoubtedly produces sound waves when it falls, regardless of whether anyone is there to hear them.
#
# 2. **Philosophical Perspectives**: From a philosophical standpoint, this question delves into aspects of idealism and realism. Idealists, like Berkeley, suggest that things only exist as they are perceived; therefore, if no one is there to perceive the sound, it can be argued that it does not "exist." In contrast, realists would assert that the tree falling generates sound waves independent of observation, affirming that reality exists regardless of human perception.
#
# 3. **Role of Observation**: This thought experiment underscores the importance of observation in defining reality. In quantum physics, for instance, the act of observation can affect the behavior of particles (as seen in experiments like the double-slit experiment). This leads to questions about whether reality is fundamentally dependent on consciousness and observation, or if it exists independently.
#
# 4. **Constructivist View**: From a constructivist perspective, our understanding of reality is shaped by our experiences and observations. In this view, sound does not merely exist as a phenomenon but is also an experiential process that requires an observer to fully realize it. Thus, the experience of sound is a construct of both the physical event and the consciousness interpreting it.
#
# 5. **Implications for Ethics and Existence**: Extending this discussion to a broader context, the implications of observation on defining reality can lead to ethical considerations about existence. If we accept that something requires observation to exist or have meaning, it invites deeper questions about the treatment of entities (such as animals, nature, or even hypothetical beings) that may exist unnoticed or unacknowledged by human observers.
#
# In conclusion, the question of whether a tree falling in an unobserved forest makes a sound opens up a rich dialogue about the nature of reality, the role of perception, and the interplay between the tangible world and human consciousness. It invites both philosophical inquiry and practical reflection on how we define and relate to the world around us—whether through scientific measurement or the subjective experience of individuals.
#
# # Response from competitor 2
#
# The classic philosophical debate posed by this question has been a topic of discussion among philosophers, physicists, and thinkers for centuries. The simplicity of the scenario belies the complexity of the implications involved in exploring the relationship between perception, sound, and reality.
#
# From a physical perspective, when a tree falls, it creates a disturbance in the air particles around it, producing a pressure wave that propagates through the air as a sound wave. This phenomenon is governed by physics laws, such as wave propagation and resonance, and does not depend on human observation or perception. The falling tree generates sound waves regardless of whether anyone is present to hear them.
#
# However, the question also raises important considerations about perception, reality, and the role of observation in shaping our understanding of the world. If no one is around to hear the falling tree, can we say that it truly makes a sound?
#
# One philosophical argument is that sound is a subjective experience that requires an observer to exist. According to this viewpoint, the presence or absence of observers is the criterion for determining whether an event constitutes a "sound." If there is no one present to perceive and interpret the pressure waves as sound, then we cannot conclude that it actually makes a sound. This perspective emphasizes the importance of observation in defining reality, suggesting that our understanding of the world is filtered through our individual perspectives.
#
# On the other hand, a more empiricist approach would argue that sound waves have physical properties independent of human perception. From this viewpoint, when a tree falls, it creates pressure waves regardless of whether anyone is present to hear them. The existence and nature of these pressure waves remain unchanged, even if no one is there to perceive or respond to them.
#
# The implications of observation in defining reality are far-reaching and complex. If observation plays a crucial role in shaping our understanding of the world, what does this say about the relationship between our minds and the external world? Does the fact that we don't observe something mean it doesn't exist?
#
# Furthermore, if sound is a subjective experience dependent on observation, then where do we draw the line between perception and reality? Can we conclude that nothing exists unless observed by an observer? This raises questions about the nature of objective truth and whether it can exist independently of human perception.
#
# In conclusion, while the tree falling in the forest creates physical pressure waves regardless of human presence, the philosophical implications of observation on defining reality are subtle but profound. The debate highlights the importance of considering perspectives and the limits of our understanding when exploring the complex relationship between perception, sound, and the external world.
#
# # Response from competitor 3
#
# Certainly! The scenario you described, where a tree falls and there's nobody to observe it, brings up an interesting question about perception vs. reality. Let's break this down step-by-step:
#
# 1. **Observation**: We perceive our world based on what we can see or be aware of at any given moment. Essentially, observation is another term for "perception". We need eyes to observe things (or tools like microphones used in the scenario above).
#
# 2. **Reality**: Reality refers to how something truly exists independent of human perception and observation. It's a fact that exists regardless of whether you're there or not.
#
# 3. **Implications of Observation**: If nobody is around to observe a falling tree, can we still say it has made a sound? The answer often depends on one's viewpoint regarding the role of observing beings in determining what constitutes "existence".
#
# From an Aristotelian perspective (a philosophical framework developed by Aristotle), existence might not come into play unless some being perceives it. According to this view, something that exists independently from observation doesn’t need our perception to be considered real.
#
# However, others would argue differently—they would say the falling tree is part of reality and we could determine if a sound was indeed made because regardless of who or what observes it, physical phenomena such as vibrations in materials (for example, wood) are observable facts about objects' states even before any human being can perceive them.
#
# In conclusion, observations play a crucial role in defining reality. Even though no one might be there to hear the sound, our understanding and definition of "a sound existing" would remain based on what we know from scientific and everyday experiences (i.e., it's real if a vibration in wood is caused by the falling tree). The observation aspect is central when determining and defining reality, as both perspectives emphasize that without any observing entity present to observe it, our understanding of existence might be incomplete—but that does not necessarily make the event or phenomena non-existent.

# %%
judge = f"""You are judging a competition between {len(competitors)} competitors.
Each model has been given this question:

{question}

Your job is to evaluate each response for clarity and strength of argument, and rank them in order of best to worst.
Respond with JSON, and only JSON, with the following format:
{{"results": ["best competitor number", "second best competitor number", "third best competitor number", ...]}}

Here are the responses from each competitor:

{together}

Now respond with the JSON with the ranked order of the competitors, nothing else. Do not include markdown formatting or code blocks."""

# %%
print(judge)
# Out:
# You are judging a competition between 3 competitors.
# Each model has been given this question:
#
# If a tree falls in a forest and no one is around to hear it, does it make a sound? Elaborate on your answer by discussing the implications of observation in defining reality.
#
# Your job is to evaluate each response for clarity and strength of argument, and rank them in order of best to worst.
# Respond with JSON, and only JSON, with the following format:
# {"results": ["best competitor number", "second best competitor number", "third best competitor number", ...]}
#
# Here are the responses from each competitor:
#
# # Response from competitor 1
#
# The philosophical question "If a tree falls in a forest and no one is around to hear it, does it make a sound?" raises intriguing discussions about perception, reality, and the role of observation in defining existence. This thought experiment touches on several themes:
#
# 1. **Definition of Sound**: To answer whether the tree makes a sound, we first need to define "sound." In a physical sense, sound is a vibration that travels through air (or other media) and can be detected by a listener's auditory system. In this interpretation, the tree undoubtedly produces sound waves when it falls, regardless of whether anyone is there to hear them.
#
# 2. **Philosophical Perspectives**: From a philosophical standpoint, this question delves into aspects of idealism and realism. Idealists, like Berkeley, suggest that things only exist as they are perceived; therefore, if no one is there to perceive the sound, it can be argued that it does not "exist." In contrast, realists would assert that the tree falling generates sound waves independent of observation, affirming that reality exists regardless of human perception.
#
# 3. **Role of Observation**: This thought experiment underscores the importance of observation in defining reality. In quantum physics, for instance, the act of observation can affect the behavior of particles (as seen in experiments like the double-slit experiment). This leads to questions about whether reality is fundamentally dependent on consciousness and observation, or if it exists independently.
#
# 4. **Constructivist View**: From a constructivist perspective, our understanding of reality is shaped by our experiences and observations. In this view, sound does not merely exist as a phenomenon but is also an experiential process that requires an observer to fully realize it. Thus, the experience of sound is a construct of both the physical event and the consciousness interpreting it.
#
# 5. **Implications for Ethics and Existence**: Extending this discussion to a broader context, the implications of observation on defining reality can lead to ethical considerations about existence. If we accept that something requires observation to exist or have meaning, it invites deeper questions about the treatment of entities (such as animals, nature, or even hypothetical beings) that may exist unnoticed or unacknowledged by human observers.
#
# In conclusion, the question of whether a tree falling in an unobserved forest makes a sound opens up a rich dialogue about the nature of reality, the role of perception, and the interplay between the tangible world and human consciousness. It invites both philosophical inquiry and practical reflection on how we define and relate to the world around us—whether through scientific measurement or the subjective experience of individuals.
#
# # Response from competitor 2
#
# The classic philosophical debate posed by this question has been a topic of discussion among philosophers, physicists, and thinkers for centuries. The simplicity of the scenario belies the complexity of the implications involved in exploring the relationship between perception, sound, and reality.
#
# From a physical perspective, when a tree falls, it creates a disturbance in the air particles around it, producing a pressure wave that propagates through the air as a sound wave. This phenomenon is governed by physics laws, such as wave propagation and resonance, and does not depend on human observation or perception. The falling tree generates sound waves regardless of whether anyone is present to hear them.
#
# However, the question also raises important considerations about perception, reality, and the role of observation in shaping our understanding of the world. If no one is around to hear the falling tree, can we say that it truly makes a sound?
#
# One philosophical argument is that sound is a subjective experience that requires an observer to exist. According to this viewpoint, the presence or absence of observers is the criterion for determining whether an event constitutes a "sound." If there is no one present to perceive and interpret the pressure waves as sound, then we cannot conclude that it actually makes a sound. This perspective emphasizes the importance of observation in defining reality, suggesting that our understanding of the world is filtered through our individual perspectives.
#
# On the other hand, a more empiricist approach would argue that sound waves have physical properties independent of human perception. From this viewpoint, when a tree falls, it creates pressure waves regardless of whether anyone is present to hear them. The existence and nature of these pressure waves remain unchanged, even if no one is there to perceive or respond to them.
#
# The implications of observation in defining reality are far-reaching and complex. If observation plays a crucial role in shaping our understanding of the world, what does this say about the relationship between our minds and the external world? Does the fact that we don't observe something mean it doesn't exist?
#
# Furthermore, if sound is a subjective experience dependent on observation, then where do we draw the line between perception and reality? Can we conclude that nothing exists unless observed by an observer? This raises questions about the nature of objective truth and whether it can exist independently of human perception.
#
# In conclusion, while the tree falling in the forest creates physical pressure waves regardless of human presence, the philosophical implications of observation on defining reality are subtle but profound. The debate highlights the importance of considering perspectives and the limits of our understanding when exploring the complex relationship between perception, sound, and the external world.
#
# # Response from competitor 3
#
# Certainly! The scenario you described, where a tree falls and there's nobody to observe it, brings up an interesting question about perception vs. reality. Let's break this down step-by-step:
#
# 1. **Observation**: We perceive our world based on what we can see or be aware of at any given moment. Essentially, observation is another term for "perception". We need eyes to observe things (or tools like microphones used in the scenario above).
#
# 2. **Reality**: Reality refers to how something truly exists independent of human perception and observation. It's a fact that exists regardless of whether you're there or not.
#
# 3. **Implications of Observation**: If nobody is around to observe a falling tree, can we still say it has made a sound? The answer often depends on one's viewpoint regarding the role of observing beings in determining what constitutes "existence".
#
# From an Aristotelian perspective (a philosophical framework developed by Aristotle), existence might not come into play unless some being perceives it. According to this view, something that exists independently from observation doesn’t need our perception to be considered real.
#
# However, others would argue differently—they would say the falling tree is part of reality and we could determine if a sound was indeed made because regardless of who or what observes it, physical phenomena such as vibrations in materials (for example, wood) are observable facts about objects' states even before any human being can perceive them.
#
# In conclusion, observations play a crucial role in defining reality. Even though no one might be there to hear the sound, our understanding and definition of "a sound existing" would remain based on what we know from scientific and everyday experiences (i.e., it's real if a vibration in wood is caused by the falling tree). The observation aspect is central when determining and defining reality, as both perspectives emphasize that without any observing entity present to observe it, our understanding of existence might be incomplete—but that does not necessarily make the event or phenomena non-existent.
#
#
#
# Now respond with the JSON with the ranked order of the competitors, nothing else. Do not include markdown formatting or code blocks.

# %%
judge_messages = [{"role": "user", "content": judge}]

# %%
# Judgement time!

openai = OpenAI()
response = openai.chat.completions.create(
    model="o3-mini",
    messages=judge_messages,
)
results = response.choices[0].message.content
print(results)
# Out:
# {"results": ["1", "2", "3"]}

# %%
# OK let's turn this into results!

results_dict = json.loads(results)
ranks = results_dict["results"]
for index, result in enumerate(ranks):
    competitor = competitors[int(result)-1]
    print(f"Rank {index+1}: {competitor}")
# Out:
# Rank 1: gpt-4o-mini
# Rank 2: llama3.2
# Rank 3: smollm2

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Which pattern(s) did this use? Try updating this to add another Agentic design pattern.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">Commercial implications</h2>
#             <span style="color:#00bfff;">These kinds of patterns - to send a task to multiple models, and evaluate results,
#             and common where you need to improve the quality of your LLM response. This approach can be universally applied
#             to business projects where accuracy is critical.
#             </span>
#         </td>
#     </tr>
# </table>
